# %%
import pandas as pd

# load imdb csv file into dataframe
df = pd.read_csv("../data/kaggle/movie_metadata.csv" )
imdb = df[df.gross > 0]
imdb.loc[:,['movie_title','director_name','gross','budget','content_rating']]
# Out:
# /Users/livfranzen/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#                                        movie_title       director_name  \
# 0                                          Avatar        James Cameron
# 1        Pirates of the Caribbean: At World's End       Gore Verbinski
# 2                                         Spectre           Sam Mendes
# 3                           The Dark Knight Rises    Christopher Nolan
# 5                                     John Carter       Andrew Stanton
# 6                                    Spider-Man 3            Sam Raimi
# 7                                         Tangled         Nathan Greno
# 8                         Avengers: Age of Ultron          Joss Whedon
# 9          Harry Potter and the Half-Blood Prince          David Yates
# 10             Batman v Superman: Dawn of Justice          Zack Snyder
# ...

# %%
noRating = imbd[imbd.content_rating == 'Not Rated']

# %%
noRating.loc[:,['movie_title','director_name','gross','budget','content_rating','title_year']]
# Out:
#                                             movie_title  \
# 2007                                 Little White Lies
# 2588                                    Enter the Void
# 2734                                        Metropolis
# 2737                                      The Assassin
# 2761                                         Manderlay
# 2992                                  The Great Beauty
# 3219                                   The Brown Bunny
# 3276                                  Jab Tak Hai Jaan
# 3318                                  Flame and Citron
# 3408                               The Secret of Kells
# 3682                                          Le Havre
# 3839                                      Savage Grace
# 3890                        The Greatest Show on Earth
# 4107                               Hobo with a Shotgun
# 4155                                  Some Like It Hot
# 4200                                              Fuel
# ...

# %%
noRating.index
# Out:
# Int64Index([2007, 2588, 2734, 2737, 2761, 2992, 3219, 3276, 3318, 3408, 3682,
#             3839, 3890, 4107, 4155, 4200, 4238, 4328, 4333, 4434, 4465, 4502,
#             4585, 4601, 4638, 4640, 4670, 4671, 4679, 4748, 4750, 4758, 4814,
#             4838, 4890, 4922, 4964, 4987, 5009, 5027, 5034, 5037],
#            dtype='int64')

# %%
noRating.shape
# Out:
# (42, 28)

# %%
unRating = imbd[imbd.content_rating == 'Unrated']

# %%
unRating.shape
# Out:
# (24, 28)

# %%
unRating.head(24)
# Out:
#                  color          director_name  num_critic_for_reviews  \
# 2813             Color           Costa-Gavras                    69.0
# 3421             Color      Thomas Vinterberg                   100.0
# 3588             Color         Jerome Robbins                   120.0
# 3596             Color             King Vidor                    32.0
# 3684             Color      Hitoshi Matsumoto                    72.0
# 3707             Color           Henry Koster                    42.0
# 3941             Color        Robert Lee King                    51.0
# 3953             Color           Karim Aïnouz                    70.0
# 4057             Color            James Ivory                    55.0
# 4151             Color          Alexandre Aja                   251.0
# 4216             Color          Shane Meadows                   172.0
# 4283             Color  John Cameron Mitchell                   160.0
# ...

# %%
# https://en.wikipedia.org/wiki/Motion_picture_content_rating_system
# https://en.wikipedia.org/wiki/Motion_Picture_Association_of_America_film_rating_system
# https://contribute.imdb.com/updates/guide/certificates

imbd.content_rating.unique()
# Out:
# array(['PG-13', 'PG', 'G', 'R', 'Approved', 'NC-17', nan, 'X', 'Not Rated',
#        'Unrated', 'M', 'GP', 'Passed'], dtype=object)

# %%
imbd[imbd.content_rating.isnull()]
# Out:
#                  color          director_name  num_critic_for_reviews  \
# 1329             Color         S.S. Rajamouli                    44.0
# 1527             Color        Jeremy Degruson                    60.0
# 2014             Color             Teddy Chan                    65.0
# 2339             Color       Jean-Marie Poiré                     8.0
# 2892             Color            John H. Lee                     2.0
# 3020             Color         Akira Kurosawa                    25.0
# 3220             Color         Claude Chabrol                    34.0
# 3250             Color    Benedikt Erlingsson                    66.0
# 3273             Color            Anurag Basu                    41.0
# 3449             Color          Claude Miller                    38.0
# 3455             Color        Siddharth Anand                    16.0
# 3510             Color            Yash Chopra                    29.0
# ...
