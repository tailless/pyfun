# %%
import pandas as pd

# load imdb csv file into dataframe
imdb = pd.read_csv("./BASE_DATA.csv" )
imdb.head()
# Out:
#                                  movie_title  title_year      director_name  \
# 0                                    Avatar       2009.0      James Cameron
# 1  Pirates of the Caribbean: At World's End       2007.0     Gore Verbinski
# 2                     The Dark Knight Rises       2012.0  Christopher Nolan
# 3                               John Carter       2012.0     Andrew Stanton
# 4                              Spider-Man 3       2007.0          Sam Raimi
#
#          gross       budget  content_rating country  duration  \
# 0  760505847.0  237000000.0               3     USA     178.0
# 1  309404152.0  300000000.0               3     USA     169.0
# 2  448130642.0  250000000.0               3     USA     164.0
# 3   73058679.0  263700000.0               3     USA     132.0
# 4  336530303.0  258000000.0               3     USA     156.0
#
#    actor_1_facebook_likes                           genres   f_adj_gross  \
# ...

# %%
imdb['ROI_band'] = 0
imdb['profit_in_dollars'] = 0
imdb.profit_in_dollars = (imdb['gross'] - imdb['budget'])
imdb.head()
# Out:
#                                  movie_title  title_year      director_name  \
# 0                                    Avatar       2009.0      James Cameron
# 1  Pirates of the Caribbean: At World's End       2007.0     Gore Verbinski
# 2                     The Dark Knight Rises       2012.0  Christopher Nolan
# 3                               John Carter       2012.0     Andrew Stanton
# 4                              Spider-Man 3       2007.0          Sam Raimi
#
#          gross       budget  content_rating country  duration  \
# 0  760505847.0  237000000.0               3     USA     178.0
# 1  309404152.0  300000000.0               3     USA     169.0
# 2  448130642.0  250000000.0               3     USA     164.0
# 3   73058679.0  263700000.0               3     USA     132.0
# 4  336530303.0  258000000.0               3     USA     156.0
#
#    actor_1_facebook_likes                           genres   f_adj_gross  \
# ...

# %%
imdb['ROI_percent'] = 0
imdb.loc[(imdb.profit > 0), 'ROI_percent'] = ( imdb['gross'] / imdb['budget'])* 100
imdb.head(20)
# Out:
#                                      movie_title  title_year  \
# 0                                        Avatar       2009.0
# 1      Pirates of the Caribbean: At World's End       2007.0
# 2                         The Dark Knight Rises       2012.0
# 3                                   John Carter       2012.0
# 4                                  Spider-Man 3       2007.0
# 5                                       Tangled       2010.0
# 6                       Avengers: Age of Ultron       2015.0
# 7            Batman v Superman: Dawn of Justice       2016.0
# 8                              Superman Returns       2006.0
# 9    Pirates of the Caribbean: Dead Man's Chest       2006.0
# 10                              The Lone Ranger       2013.0
# 11                                 Man of Steel       2013.0
# 12     The Chronicles of Narnia: Prince Caspian       2008.0
# 13                                 The Avengers       2012.0
# ...

# %%
successfulMovies = imdb[(imdb.profit > 0)]
successfulMovies.ROI_percent.describe()
# Out:
# count      1693.000000
# mean       1094.715847
# std       18468.999199
# min         100.014336
# 25%         141.814182
# 50%         211.615040
# 75%         375.294517
# max      719448.553333
# Name: ROI_percent, dtype: float64

# %%
# %matplotlib inline
successfulMovies.plot.scatter(x='budget', y='ROI_percent')

# %%
# %matplotlib inline
from scipy import stats, integrate
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)
sns.distplot(successfulMovies.profit_in_dollars)
# Out:
# /Users/livfranzen/anaconda3/lib/python3.6/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.distplot(successfulMovies.profit_in_dollars, kde=False, rug=True);

# %%
sns.distplot(successfulMovies.profit_in_dollars, bins=20, kde=False, rug=True);

# %%
highestROI = imdb[(imdb.ROI_percent > 10000)]
highestROI
# Out:
#                         movie_title  title_year     director_name  \
# 1885                     Halloween       1978.0    John Carpenter
# 2335  The Texas Chain Saw Massacre       1974.0       Tobe Hooper
# 2796                         Rocky       1976.0  John G. Avildsen
# 2844             American Graffiti       1973.0      George Lucas
# 2855       The Blair Witch Project       1999.0     Daniel Myrick
# 2881             Napoleon Dynamite       2004.0        Jared Hess
# 2883           Paranormal Activity       2007.0         Oren Peli
# 2921             Facing the Giants       2006.0     Alex Kendrick
# 2922                   The Gallows       2015.0      Travis Cluff
# 2927                 Super Size Me       2004.0   Morgan Spurlock
# 2930         The Brothers McMullen       1995.0      Edward Burns
# 2938                   El Mariachi       1992.0  Robert Rodriguez
#
#             gross    budget  content_rating country  duration  \
# ...

# %%
highestROI.shape
# Out:
# (12, 17)

# %%
bins = [100, 150, 200, 400, 800, 1600, 3200, 6400, 12800, 15600, 31200, 62400, 124800, 249600, 499200, 998400]
imdb.ROI_band = pd.cut(imdb.ROI_percent, bins)

imdb.head(20)
# Out:
#                                      movie_title  title_year  \
# 0                                        Avatar       2009.0
# 1      Pirates of the Caribbean: At World's End       2007.0
# 2                         The Dark Knight Rises       2012.0
# 3                                   John Carter       2012.0
# 4                                  Spider-Man 3       2007.0
# 5                                       Tangled       2010.0
# 6                       Avengers: Age of Ultron       2015.0
# 7            Batman v Superman: Dawn of Justice       2016.0
# 8                              Superman Returns       2006.0
# 9    Pirates of the Caribbean: Dead Man's Chest       2006.0
# 10                              The Lone Ranger       2013.0
# 11                                 Man of Steel       2013.0
# 12     The Chronicles of Narnia: Prince Caspian       2008.0
# 13                                 The Avengers       2012.0
# ...

# %%
# Write rate adjusted dataframe to csv
imdb.to_csv("./movies_with_ROI.csv", index=False, encoding="utf-8")

# %%
#imdb.loc[(imdb.ROI_band == NaN), 'ROI_band'] = 0

# %%
sns.jointplot(x="x", y="y", data=successfulMovies, kind="kde");
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-70f73b5a1f5e> in <module>()
# ----> 1 sns.jointplot(x="x", y="y", data=successfulMovies, kind="kde");
#
# /Users/livfranzen/anaconda3/lib/python3.6/site-packages/seaborn/distributions.py in jointplot(x, y, data, kind, stat_func, color, size, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#     796     grid = JointGrid(x, y, data, dropna=dropna,
#     797                      size=size, ratio=ratio, space=space,
# --> 798                      xlim=xlim, ylim=ylim)
#     799
#     800     # Plot the data using the grid
#
# /Users/livfranzen/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py in __init__(self, x, y, data, size, ratio, space, dropna, xlim, ylim)
#    1658         if dropna:
#    1659             not_na = pd.notnull(x) & pd.notnull(y)
# ...
